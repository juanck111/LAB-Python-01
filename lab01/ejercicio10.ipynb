# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-01/blob/main/lab01/ejercicio10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://jsonplaceholder.typicode.com/users"
response = requests.get(url)
usuarios = response.json()

usuarios_biz = [u["name"] for u in usuarios if u["email"].endswith(".biz")]

print("Usuarios con correo .biz:")
for n in usuarios_biz:
    print("-", n)
# Out:
# Usuarios con correo .biz:
# - Leanne Graham
# - Kurtis Weissnat
# - Clementina DuBuque
