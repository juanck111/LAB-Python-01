# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-01/blob/main/lab01/ejercicio08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
suma_pares = 0
suma_impares = 0

for i in range(1, 11):
    if i % 2 == 0:
        suma_pares += i
    else:
        suma_impares += i

estado_final = {"suma_pares": suma_pares, "suma_impares": suma_impares}
print("Estado final:", estado_final)
# Out:
# Estado final: {'suma_pares': 30, 'suma_impares': 25}
