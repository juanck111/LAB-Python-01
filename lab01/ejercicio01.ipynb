# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-01/blob/main/lab01/ejercicio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Modificación para ingresar datos por teclado
saldo = float(input("Ingrese el saldo inicial: "))
deposito = float(input("Ingrese el monto a depositar: "))
retiro = float(input("Ingrese el monto a retirar: "))

# Actualización del estado
saldo = saldo + deposito
saldo = saldo - retiro

# Nuevas variables
interes = 0.02
saldo_final = saldo + (saldo * interes)

# Salida usando f-string
print(f"Saldo final con interés: ${saldo_final:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30402/3545218483.py in <cell line: 0>()
#       1 # Modificación para ingresar datos por teclado
# ----> 2 saldo = float(input("Ingrese el saldo inicial: "))
#       3 deposito = float(input("Ingrese el monto a depositar: "))
#       4 retiro = float(input("Ingrese el monto a retirar: "))
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
