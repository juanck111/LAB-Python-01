# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-01/blob/main/lab01/ejercicio05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad = int(input("Ingrese su edad: "))
tiene_licencia = input("¿Tiene licencia? (s/n): ").lower()
sancionado = input("¿Está sancionado actualmente? (s/n): ").lower()

if edad >= 18 and tiene_licencia == 's' and sancionado == 'n':
    print("Usted puede conducir.")
else:
    print("No cumple con los requisitos para conducir.")
# Out:
# Ingrese su edad: 20
# ¿Tiene licencia? (s/n): s
# ¿Está sancionado actualmente? (s/n): n
# Usted puede conducir.
