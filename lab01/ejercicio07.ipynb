# %% [markdown]
# <a href="https://colab.research.google.com/github/juanck111/LAB-Python-01/blob/main/lab01/ejercicio07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contador = 5
while contador > 0:
    print("Cuenta regresiva:", contador)
    contador -= 1

while True:
    num = int(input("Ingrese un número (0 para salir): "))
    if num == 0:
        break
# Out:
# Cuenta regresiva: 5
# Cuenta regresiva: 4
# Cuenta regresiva: 3
# Cuenta regresiva: 2
# Cuenta regresiva: 1
# Ingrese un número (0 para salir): 0
